# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv("incomplete_lyrics.csv")

# %%
data['album']=""
data['year']=0

# %%
data.head()
# Out:
#                                               lyrics         title album  year
# 0  <div>\n<!-- Usage of azlyrics.com content by a...       Bastard           0
# 1  <div>\n<!-- Usage of azlyrics.com content by a...         Seven           0
# 2  <div>\n<!-- Usage of azlyrics.com content by a...  Odd Toddlers           0
# 3  <div>\n<!-- Usage of azlyrics.com content by a...       French!           0
# 4  <div>\n<!-- Usage of azlyrics.com content by a...          Blow           0

# %%
for i in list(range(0,15)):
    data['album'][i] = 'Bastard'
    data['year'][i] = 2009
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[0:16]
# Out:
#                                                lyrics                   title  \
# 0   <div>\n<!-- Usage of azlyrics.com content by a...                 Bastard
# 1   <div>\n<!-- Usage of azlyrics.com content by a...                   Seven
# 2   <div>\n<!-- Usage of azlyrics.com content by a...            Odd Toddlers
# 3   <div>\n<!-- Usage of azlyrics.com content by a...                 French!
# 4   <div>\n<!-- Usage of azlyrics.com content by a...                    Blow
# 5   <div>\n<!-- Usage of azlyrics.com content by a...                Pigs Fly
# 6   <div>\n<!-- Usage of azlyrics.com content by a...                  Parade
# 7   <div>\n<!-- Usage of azlyrics.com content by a...            Slow It Down
# 8   <div>\n<!-- Usage of azlyrics.com content by a...                 AssMilk
# 9   <div>\n<!-- Usage of azlyrics.com content by a...            VCR / Wheels
# 10  <div>\n<!-- Usage of azlyrics.com content by a...                 Session
# 11  <div>\n<!-- Usage of azlyrics.com content by a...                   Sarah
# 12  <div>\n<!-- Usage of azlyrics.com content by a...  Jack And The Beanstalk
# 13  <div>\n<!-- Usage of azlyrics.com content by a...                    Tina
# 14  <div>\n<!-- Usage of azlyrics.com content by a...              Inglorious
# 15  <div>\n<!-- Usage of azlyrics.com content by a...                  Goblin
#
#       album  year
# 0   Bastard  2009
# 1   Bastard  2009
# 2   Bastard  2009
# 3   Bastard  2009
# 4   Bastard  2009
# 5   Bastard  2009
# 6   Bastard  2009
# 7   Bastard  2009
# 8   Bastard  2009
# 9   Bastard  2009
# 10  Bastard  2009
# 11  Bastard  2009
# 12  Bastard  2009
# 13  Bastard  2009
# 14  Bastard  2009
# 15              0

# %%
data.iloc[15:32]
# Out:
#                                                lyrics            title album  \
# 15  <div>\n<!-- Usage of azlyrics.com content by a...           Goblin
# 16  <div>\n<!-- Usage of azlyrics.com content by a...          Yonkers
# 17  <div>\n<!-- Usage of azlyrics.com content by a...         Radicals
# 18  <div>\n<!-- Usage of azlyrics.com content by a...              She
# 19  <div>\n<!-- Usage of azlyrics.com content by a...     Transylvania
# 20  <div>\n<!-- Usage of azlyrics.com content by a...        Nightmare
# 21  <div>\n<!-- Usage of azlyrics.com content by a...         Tron Cat
# 22  <div>\n<!-- Usage of azlyrics.com content by a...              Her
# 23  <div>\n<!-- Usage of azlyrics.com content by a...      Sandwitches
# 24  <div>\n<!-- Usage of azlyrics.com content by a...             Fish
# 25  <div>\n<!-- Usage of azlyrics.com content by a...    Boppin' Bitch
# 26  <div>\n<!-- Usage of azlyrics.com content by a...           Analog
# 27  <div>\n<!-- Usage of azlyrics.com content by a...  Bitch Suck Dick
# 28  <div>\n<!-- Usage of azlyrics.com content by a...           Window
# 29  <div>\n<!-- Usage of azlyrics.com content by a...           Golden
# 30  <div>\n<!-- Usage of azlyrics.com content by a...           Burger
# 31  <div>\n<!-- Usage of azlyrics.com content by a...      Steak Sauce
#
#     year
# 15     0
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     0
# 30     0
# 31     0

# %%
for i in list(range(15,32)):
    data['album'][i] = 'Goblin'
    data['year'][i] = 2011
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[15:33]
# Out:
#                                                lyrics            title  \
# 15  <div>\n<!-- Usage of azlyrics.com content by a...           Goblin
# 16  <div>\n<!-- Usage of azlyrics.com content by a...          Yonkers
# 17  <div>\n<!-- Usage of azlyrics.com content by a...         Radicals
# 18  <div>\n<!-- Usage of azlyrics.com content by a...              She
# 19  <div>\n<!-- Usage of azlyrics.com content by a...     Transylvania
# 20  <div>\n<!-- Usage of azlyrics.com content by a...        Nightmare
# 21  <div>\n<!-- Usage of azlyrics.com content by a...         Tron Cat
# 22  <div>\n<!-- Usage of azlyrics.com content by a...              Her
# 23  <div>\n<!-- Usage of azlyrics.com content by a...      Sandwitches
# 24  <div>\n<!-- Usage of azlyrics.com content by a...             Fish
# 25  <div>\n<!-- Usage of azlyrics.com content by a...    Boppin' Bitch
# 26  <div>\n<!-- Usage of azlyrics.com content by a...           Analog
# 27  <div>\n<!-- Usage of azlyrics.com content by a...  Bitch Suck Dick
# 28  <div>\n<!-- Usage of azlyrics.com content by a...           Window
# 29  <div>\n<!-- Usage of azlyrics.com content by a...           Golden
# 30  <div>\n<!-- Usage of azlyrics.com content by a...           Burger
# 31  <div>\n<!-- Usage of azlyrics.com content by a...      Steak Sauce
# 32  <div>\n<!-- Usage of azlyrics.com content by a...             Wolf
#
#      album  year
# 15  Goblin  2011
# 16  Goblin  2011
# 17  Goblin  2011
# 18  Goblin  2011
# 19  Goblin  2011
# 20  Goblin  2011
# 21  Goblin  2011
# 22  Goblin  2011
# 23  Goblin  2011
# 24  Goblin  2011
# 25  Goblin  2011
# 26  Goblin  2011
# 27  Goblin  2011
# 28  Goblin  2011
# 29  Goblin  2011
# 30  Goblin  2011
# 31  Goblin  2011
# 32             0

# %%
data.iloc[32:50]
# Out:
#                                                lyrics  \
# 32  <div>\n<!-- Usage of azlyrics.com content by a...
# 33  <div>\n<!-- Usage of azlyrics.com content by a...
# 34  <div>\n<!-- Usage of azlyrics.com content by a...
# 35  <div>\n<!-- Usage of azlyrics.com content by a...
# 36  <div>\n<!-- Usage of azlyrics.com content by a...
# 37  <div>\n<!-- Usage of azlyrics.com content by a...
# 38  <div>\n<!-- Usage of azlyrics.com content by a...
# 39  <div>\n<!-- Usage of azlyrics.com content by a...
# 40  <div>\n<!-- Usage of azlyrics.com content by a...
# 41  <div>\n<!-- Usage of azlyrics.com content by a...
# 42  <div>\n<!-- Usage of azlyrics.com content by a...
# 43  <div>\n<!-- Usage of azlyrics.com content by a...
# 44  <div>\n<!-- Usage of azlyrics.com content by a...
# 45  <div>\n<!-- Usage of azlyrics.com content by a...
# 46  <div>\n<!-- Usage of azlyrics.com content by a...
# 47  <div>\n<!-- Usage of azlyrics.com content by a...
# 48  <div>\n<!-- Usage of azlyrics.com content by a...
# 49  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                                 title album  year
# 32                               Wolf           0
# 33                              Jamba           0
# 34                             Cowboy           0
# 35                            Awkward           0
# 36                             Domo23           0
# 37                             Answer           0
# 38                             Slater           0
# 39                                 48           0
# 40                           Colossus           0
# 41  PartyIsntOver / Campfire / Bimmer           0
# 42                               IFHY           0
# 43                               Pigs           0
# 44                        Parking Lot           0
# 45                              Rusty           0
# 46                          Trashwang           0
# 47                         Treehome95           0
# 48                             Tamale           0
# 49                               Lone           0

# %%
for i in list(range(32,50)):
    data['album'][i] = 'Wolf'
    data['year'][i] = 2013
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[32:51]
# Out:
#                                                lyrics  \
# 32  <div>\n<!-- Usage of azlyrics.com content by a...
# 33  <div>\n<!-- Usage of azlyrics.com content by a...
# 34  <div>\n<!-- Usage of azlyrics.com content by a...
# 35  <div>\n<!-- Usage of azlyrics.com content by a...
# 36  <div>\n<!-- Usage of azlyrics.com content by a...
# 37  <div>\n<!-- Usage of azlyrics.com content by a...
# 38  <div>\n<!-- Usage of azlyrics.com content by a...
# 39  <div>\n<!-- Usage of azlyrics.com content by a...
# 40  <div>\n<!-- Usage of azlyrics.com content by a...
# 41  <div>\n<!-- Usage of azlyrics.com content by a...
# 42  <div>\n<!-- Usage of azlyrics.com content by a...
# 43  <div>\n<!-- Usage of azlyrics.com content by a...
# 44  <div>\n<!-- Usage of azlyrics.com content by a...
# 45  <div>\n<!-- Usage of azlyrics.com content by a...
# 46  <div>\n<!-- Usage of azlyrics.com content by a...
# 47  <div>\n<!-- Usage of azlyrics.com content by a...
# 48  <div>\n<!-- Usage of azlyrics.com content by a...
# 49  <div>\n<!-- Usage of azlyrics.com content by a...
# 50  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                                 title album  year
# 32                               Wolf  Wolf  2013
# 33                              Jamba  Wolf  2013
# 34                             Cowboy  Wolf  2013
# 35                            Awkward  Wolf  2013
# 36                             Domo23  Wolf  2013
# 37                             Answer  Wolf  2013
# 38                             Slater  Wolf  2013
# 39                                 48  Wolf  2013
# 40                           Colossus  Wolf  2013
# 41  PartyIsntOver / Campfire / Bimmer  Wolf  2013
# 42                               IFHY  Wolf  2013
# 43                               Pigs  Wolf  2013
# 44                        Parking Lot  Wolf  2013
# 45                              Rusty  Wolf  2013
# 46                          Trashwang  Wolf  2013
# 47                         Treehome95  Wolf  2013
# 48                             Tamale  Wolf  2013
# 49                               Lone  Wolf  2013
# 50                          DEATHCAMP           0

# %%
data.iloc[50:65]
# Out:
#                                                lyrics  \
# 50  <div>\n<!-- Usage of azlyrics.com content by a...
# 51  <div>\n<!-- Usage of azlyrics.com content by a...
# 52  <div>\n<!-- Usage of azlyrics.com content by a...
# 53  <div>\n<!-- Usage of azlyrics.com content by a...
# 54  <div>\n<!-- Usage of azlyrics.com content by a...
# 55  <div>\n<!-- Usage of azlyrics.com content by a...
# 56  <div>\n<!-- Usage of azlyrics.com content by a...
# 57  <div>\n<!-- Usage of azlyrics.com content by a...
# 58  <div>\n<!-- Usage of azlyrics.com content by a...
# 59  <div>\n<!-- Usage of azlyrics.com content by a...
# 60  <div>\n<!-- Usage of azlyrics.com content by a...
# 61  <div>\n<!-- Usage of azlyrics.com content by a...
# 62  <div>\n<!-- Usage of azlyrics.com content by a...
# 63  <div>\n<!-- Usage of azlyrics.com content by a...
# 64  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                                                 title album  year
# 50                                          DEATHCAMP           0
# 51                                            BUFFALO           0
# 52                                              PILOT           0
# 53                                                RUN           0
# 54                                    FIND YOUR WINGS           0
# 55                                        CHERRY BOMB           0
# 56                                       BLOW MY LOAD           0
# 57                                            2SEATER           0
# 58  THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12...           0
# 59                            FUCKING YOUNG / PERFECT           0
# 60                                           SMUCKERS           0
# 61                                        KEEP DA O'S           0
# 62                                          OKAGA, CA           0
# 63                                             Yellow           0
# 64                                            Special           0

# %%
for i in list(range(50,65)):
    data['album'][i] = 'Cherry Bomb'
    data['year'][i] = 2015
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[50:66]
# Out:
#                                                lyrics  \
# 50  <div>\n<!-- Usage of azlyrics.com content by a...
# 51  <div>\n<!-- Usage of azlyrics.com content by a...
# 52  <div>\n<!-- Usage of azlyrics.com content by a...
# 53  <div>\n<!-- Usage of azlyrics.com content by a...
# 54  <div>\n<!-- Usage of azlyrics.com content by a...
# 55  <div>\n<!-- Usage of azlyrics.com content by a...
# 56  <div>\n<!-- Usage of azlyrics.com content by a...
# 57  <div>\n<!-- Usage of azlyrics.com content by a...
# 58  <div>\n<!-- Usage of azlyrics.com content by a...
# 59  <div>\n<!-- Usage of azlyrics.com content by a...
# 60  <div>\n<!-- Usage of azlyrics.com content by a...
# 61  <div>\n<!-- Usage of azlyrics.com content by a...
# 62  <div>\n<!-- Usage of azlyrics.com content by a...
# 63  <div>\n<!-- Usage of azlyrics.com content by a...
# 64  <div>\n<!-- Usage of azlyrics.com content by a...
# 65  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                                                 title        album  year
# 50                                          DEATHCAMP  Cherry Bomb  2015
# 51                                            BUFFALO  Cherry Bomb  2015
# 52                                              PILOT  Cherry Bomb  2015
# 53                                                RUN  Cherry Bomb  2015
# 54                                    FIND YOUR WINGS  Cherry Bomb  2015
# 55                                        CHERRY BOMB  Cherry Bomb  2015
# 56                                       BLOW MY LOAD  Cherry Bomb  2015
# 57                                            2SEATER  Cherry Bomb  2015
# 58  THE BROWN STAINS OF DARKEESE LATIFAH PART 6-12...  Cherry Bomb  2015
# 59                            FUCKING YOUNG / PERFECT  Cherry Bomb  2015
# 60                                           SMUCKERS  Cherry Bomb  2015
# 61                                        KEEP DA O'S  Cherry Bomb  2015
# 62                                          OKAGA, CA  Cherry Bomb  2015
# 63                                             Yellow  Cherry Bomb  2015
# 64                                            Special  Cherry Bomb  2015
# 65                                           Foreword                  0

# %%
data.iloc[65:78]
# Out:
#                                                lyrics  \
# 65  <div>\n<!-- Usage of azlyrics.com content by a...
# 66  <div>\n<!-- Usage of azlyrics.com content by a...
# 67  <div>\n<!-- Usage of azlyrics.com content by a...
# 68  <div>\n<!-- Usage of azlyrics.com content by a...
# 69  <div>\n<!-- Usage of azlyrics.com content by a...
# 70  <div>\n<!-- Usage of azlyrics.com content by a...
# 71  <div>\n<!-- Usage of azlyrics.com content by a...
# 72  <div>\n<!-- Usage of azlyrics.com content by a...
# 73  <div>\n<!-- Usage of azlyrics.com content by a...
# 74  <div>\n<!-- Usage of azlyrics.com content by a...
# 75  <div>\n<!-- Usage of azlyrics.com content by a...
# 76  <div>\n<!-- Usage of azlyrics.com content by a...
# 77  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                        title album  year
# 65                  Foreword           0
# 66  Where This Flower Blooms           0
# 67              Sometimes...           0
# 68             See You Again           0
# 69               Who Dat Boy           0
# 70                   Pothole           0
# 71               Garden Shed           0
# 72                   Boredom           0
# 73         I Ain't Got Time!           0
# 74          911 / Mr. Lonely           0
# 75            Droppin' Seeds           0
# 76                  November           0
# 77                   Glitter           0

# %%
for i in list(range(65,78)):
    data['album'][i] = 'Flower Boy'
    data['year'][i] = 2017
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[64:79]
# Out:
#                                                lyrics  \
# 64  <div>\n<!-- Usage of azlyrics.com content by a...
# 65  <div>\n<!-- Usage of azlyrics.com content by a...
# 66  <div>\n<!-- Usage of azlyrics.com content by a...
# 67  <div>\n<!-- Usage of azlyrics.com content by a...
# 68  <div>\n<!-- Usage of azlyrics.com content by a...
# 69  <div>\n<!-- Usage of azlyrics.com content by a...
# 70  <div>\n<!-- Usage of azlyrics.com content by a...
# 71  <div>\n<!-- Usage of azlyrics.com content by a...
# 72  <div>\n<!-- Usage of azlyrics.com content by a...
# 73  <div>\n<!-- Usage of azlyrics.com content by a...
# 74  <div>\n<!-- Usage of azlyrics.com content by a...
# 75  <div>\n<!-- Usage of azlyrics.com content by a...
# 76  <div>\n<!-- Usage of azlyrics.com content by a...
# 77  <div>\n<!-- Usage of azlyrics.com content by a...
# 78  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                        title        album  year
# 64                   Special  Cherry Bomb  2015
# 65                  Foreword   Flower Boy  2017
# 66  Where This Flower Blooms   Flower Boy  2017
# 67              Sometimes...   Flower Boy  2017
# 68             See You Again   Flower Boy  2017
# 69               Who Dat Boy   Flower Boy  2017
# 70                   Pothole   Flower Boy  2017
# 71               Garden Shed   Flower Boy  2017
# 72                   Boredom   Flower Boy  2017
# 73         I Ain't Got Time!   Flower Boy  2017
# 74          911 / Mr. Lonely   Flower Boy  2017
# 75            Droppin' Seeds   Flower Boy  2017
# 76                  November   Flower Boy  2017
# 77                   Glitter   Flower Boy  2017
# 78                 Lights On                  0

# %%
data.iloc[78:82]
# Out:
#                                                lyrics                 title  \
# 78  <div>\n<!-- Usage of azlyrics.com content by a...             Lights On
# 79  <div>\n<!-- Usage of azlyrics.com content by a...         Hot Chocolate
# 80  <div>\n<!-- Usage of azlyrics.com content by a...               Big Bag
# 81  <div>\n<!-- Usage of azlyrics.com content by a...  When Gloves Come Off
#
#    album  year
# 78           0
# 79           0
# 80           0
# 81           0

# %%
for i in list(range(78,82)):
    data['album'][i] = "Music Inspired By Illumination & Dr. Seuss' The Grinch"
    data['year'][i] = 2018
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.iloc[77:83]
# Out:
#                                                lyrics                 title  \
# 77  <div>\n<!-- Usage of azlyrics.com content by a...               Glitter
# 78  <div>\n<!-- Usage of azlyrics.com content by a...             Lights On
# 79  <div>\n<!-- Usage of azlyrics.com content by a...         Hot Chocolate
# 80  <div>\n<!-- Usage of azlyrics.com content by a...               Big Bag
# 81  <div>\n<!-- Usage of azlyrics.com content by a...  When Gloves Come Off
# 82  <div>\n<!-- Usage of azlyrics.com content by a...          IGOR'S THEME
#
#                                                 album  year
# 77                                         Flower Boy  2017
# 78  Music Inspired By Illumination & Dr. Seuss' Th...  2018
# 79  Music Inspired By Illumination & Dr. Seuss' Th...  2018
# 80  Music Inspired By Illumination & Dr. Seuss' Th...  2018
# 81  Music Inspired By Illumination & Dr. Seuss' Th...  2018
# 82                                                        0

# %%
data.iloc[82:94]
# Out:
#                                                lyrics  \
# 82  <div>\n<!-- Usage of azlyrics.com content by a...
# 83  <div>\n<!-- Usage of azlyrics.com content by a...
# 84  <div>\n<!-- Usage of azlyrics.com content by a...
# 85  <div>\n<!-- Usage of azlyrics.com content by a...
# 86  <div>\n<!-- Usage of azlyrics.com content by a...
# 87  <div>\n<!-- Usage of azlyrics.com content by a...
# 88  <div>\n<!-- Usage of azlyrics.com content by a...
# 89  <div>\n<!-- Usage of azlyrics.com content by a...
# 90  <div>\n<!-- Usage of azlyrics.com content by a...
# 91  <div>\n<!-- Usage of azlyrics.com content by a...
# 92  <div>\n<!-- Usage of azlyrics.com content by a...
# 93  <div>\n<!-- Usage of azlyrics.com content by a...
#
#                                            title album  year
# 82                                  IGOR'S THEME           0
# 83                                     EARFQUAKE           0
# 84                                       I THINK           0
# 85  EXACTLY WHAT YOU RUN FROM YOU END UP CHASING           0
# 86                           RUNNING OUT OF TIME           0
# 87                                NEW MAGIC WAND           0
# 88                                A BOY IS A GUN           0
# 89                                        PUPPET           0
# 90                                   WHAT'S GOOD           0
# 91                        GONE, GONE / THANK YOU           0
# 92                      I DON'T LOVE YOU ANYMORE           0
# 93                         ARE WE STILL FRIENDS?           0

# %%
for i in list(range(82,94)):
    data['album'][i] = "IGOR"
    data['year'][i] = 2019
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.album.value_counts()
# Out:
#                                                           19
# Wolf                                                      18
# Goblin                                                    17
# Bastard                                                   15
# Cherry Bomb                                               15
# Flower Boy                                                13
# IGOR                                                      12
# Music Inspired By Illumination & Dr. Seuss' The Grinch     4
# Name: album, dtype: int64

# %%
len(data)
# Out:
# 113

# %%
major_releases=data[
    (data['album'] == 'IGOR')
    | (data['album'] == 'Flower Boy')
    | (data['album'] == 'Cherry Bomb')
    | (data['album'] == 'Bastard')
    | (data['album'] == 'Goblin')
    | (data['album'] == 'Wolf')
    
    ]

# %%
len(major_releases)
# Out:
# 90

# %%
major_releases['lyrics'].iloc[0]
# Out:
# '<div>\n<!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->\r\nThis is what the devil plays before he goes to sleep<br/>\nSome food for thought some food for death, go \'head and fuckin\' eat<br/>\nMy father\'s dead well I don\'t know, we\'ll never fuckin\' meet<br/>\nI cut my wrist and play piano cause I\'m so depressed<br/>\nSomebody call the pastor, this bastard is so posessed<br/>\nThis meetin\' just begun, nigga I\'m Satan\'s son<br/>\n<br/>\nMy mother raised me a single parent so it\'s apparent<br/>\nThat I got love for my mother, none of you other fuckas<br/>\nAre much important I\'m gettin\' angrier while recordin\'<br/>\nI\'m feelin\' like the Bulls, I\'ve got a Gang of Wolves<br/>\nOdd Future is children that\'s fucked up on they mental<br/>\nSimple but probably not, fuck \'em<br/>\n<br/>\nI\'m tall, dark, skinny, my ears are big as fuck<br/>\nDrunk white girls the only way I\'ll get my dick sucked<br/>\nSuspended from school coolest nigga without effort<br/>\nEasy to spot like black bitches with fake leopard<br/>\nSoak me up in a tampon, but keep the lamp on<br/>\nCause this album packs enough evil<br/>\nThat you can\'t fit inside a jansport, go to school with this<br/>\n<br/>\nI go from AP to JC inside of fuckin\' week<br/>\nWakin\' up with random girls like "Yo, bitch, how the fuck we meet?"<br/>\nI stay with grandma, she always bitchin\' about her carpet<br/>\nEvery time I walk inside the house, she always tend to start shit<br/>\nNo to drugs I never spark it, I used to be bullied for honour classes<br/>\nBy those slow as molasses, take this shit to school<br/>\n<br/>\nRaquel treat me like my father like a fuckin\' stranger<br/>\nShe still don\'t know I made Sarah to strangle her<br/>\nNot put her in danger and chop her up in the back of a Wrangler<br/>\nAll because she said no to homecomin\', demons runnin\'<br/>\nInside my head tellin\' me evil thoughts<br/>\nI\'m the dream catcher but nothin\' but nightmares I caught, go to sleep<br/>\n<br/>\nI wear green hats because I\'m fortunately lucky<br/>\nFuck me the monster said, some how the monster\'s dead<br/>\nInside of me, but the thoughts it tells me are still evil<br/>\nWith this state of mind, big moves, Max Keeble<br/>\nI\'m on my grind feeble, my music is evil<br/>\nMy fuckin\' samples are too illegal, play this shit in church<br/>\n<br/>\nI graduated without honors or a fuckin\' father<br/>\nHe died, no bitch, don\'t even fuckin\' bother<br/>\nI wanted a brother my mother I told her<br/>\nBut instead I got a sister, just like me with her mister nada<br/>\nSo both of our imaginations are creations of the fuckin\' situation<br/>\nThat\'s havin\' our brains racin\' like Dayton, wearin\' some fuckin\' heelies<br/>\n<br/>\nI know you fuckin\' feel me, I want to fuckin\' kill me<br/>\nBut times I\'m so serious you think I\'m silly<br/>\nI\'m doin\' Big Style Willy couldn\'t touch 11<br/>\nSeven. What\'s religion nigga? I am Legend<br/>\nI roll with skaters and musicians with an intuition<br/>\nI created O.F. cause I feel we\'re more talented<br/>\nThan 40 year old rappers talkin\' \'bout Gucci<br/>\nWhen they have kids they haven\'t seen in years, impressin\' their peers<br/>\nWith the same problem, the only way to solve them<br/>\nIs to go to Father\'s Day convention with a gold revolver<br/>\nLife\'s a salad I\'mma toss it eat that shit up, Rick Ross it<br/>\nShit it out, bag it up sell it, I\'m so damn rebellious<br/>\nCause my mother let me do what I want<br/>\nShe wasn\'t careless, protective she is the bear<br/>\nThe shit is so bare, my diary isn\'t hid<br/>\nMy father didn\'t give a fuck, so it\'s somethin\' I inherit<br/>\nMy mom\'s all I have so it\'s never meet the parents<br/>\nWhen Danielle or Malonda decide to fuckin\' share<br/>\nThis confused boy, I wanna hug all ya, I’m bad for you kids to listen to<br/>\nSoy is not the choice, I\'m bad milk, drink it<br/>\n<br/>\nMy ...

# %%
major_releases.to_csv("major_releases.csv",index=False)

# %%
major_releases_df = pd.read_csv("major_releases.csv")

# %%
major_releases_df['album'].value_counts()
# Out:
# Wolf           18
# Goblin         17
# Bastard        15
# Cherry Bomb    15
# Flower Boy     13
# IGOR           12
# Name: album, dtype: int64

# %%
major_releases_df.head()
# Out:
#                                               lyrics         title    album  \
# 0  <div>\n<!-- Usage of azlyrics.com content by a...       Bastard  Bastard
# 1  <div>\n<!-- Usage of azlyrics.com content by a...         Seven  Bastard
# 2  <div>\n<!-- Usage of azlyrics.com content by a...  Odd Toddlers  Bastard
# 3  <div>\n<!-- Usage of azlyrics.com content by a...       French!  Bastard
# 4  <div>\n<!-- Usage of azlyrics.com content by a...          Blow  Bastard
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
major_releases_df['lyrics']=major_releases_df['lyrics'].replace('<div>\n<!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->',"")\
.replace('\r',"").replace('\n',"").replace('<br>'," ").replace('<br/>',' ').replace('</div>',"")\

# %%
for i in range(len(major_releases_df['lyrics'])):
    
    major_releases_df['lyrics'][i]=\
    major_releases_df['lyrics'][i].replace('<div>\n<!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->',"").replace('\r',"").replace('\n',"").replace('<br>'," ").replace('<br/>',' ').replace('</div>',"")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#from a heather robins lesson

corpus = list(major_releases_df['lyrics'])
corpus[1]
# Out:
# 'I\'d tell him to eat a dick quicker than Mexicans sprint over borders I give a fuck like a quarter with 20 cent At Hamptons with Fred Hampton relaxin\' at Happy Camper It\'s the fuckin\' financial aid at Hamptons wasn\'t relaxin\', I\'m taxin\' "Fuck \'em all!" I\'m chantin\', don\'t complain I\'m just rantin\' Fuck ranking, I\'m the best, I\'m the champion\'s chariot I\'m a liar like Carrey in "Liar, Liar" I\'m dirtier than the sheets in the Marriott, Cable guy like Larry Peter Pan in my youth, fucking fairies I\'m using my tooth bait to get that bitches teeth paste Fuck it, Odd Future some nazis, black nazis don\'t copy We perfect, you sloppy, huddled and slightly tacky Fuck a label on my jacket, screw you like a ratchet Screw you like a black teen on Judge Hatchett Endotherms and jaguars, drug dealers and crackers Able students and slackers I\'m backwards like Jermaine Dupri in \'93 Escaping from concentration camps with a fucking girl born in a ramp That I ordered from CCS with some diamonds that\'s VVS Like I went to Sierra Leone in a homecoming dress With some matching pink panties, lipstick from my granny Sup on my hat like that motherfucker Frannie White, red-headed bitch reminded me of Annie She dyno like my state of mind, so yeah she understand me Fuck you bunches here, never disrespect my family That’s for my little brother, sister, cousin and my auntie Wasted fuckin\' youth? All you old niggas antiques We go skate, rape sluts and eat donuts from Randy Bitches like Tia Landry watching Billy and Mandy Motherfuckers wanna be Odd but you can\'t be Sit the fuck down all you old niggas stand me, faggot  I guess I gotta be a fuckin\' hand-me-down rapper From Los Angee area anytime I\'m fuckin\' landing Fuck 2DopeBoyz and NahRight, shout out to Hype Track Them motherfuckers could never get rid of me Guess I gotta do a fucking song with Dom Kennedy Get these fuckin\' hip hop bloggers to start feelin\' me Because I\'m seventeen, compose my own beats Lyrically I\'m dope enough to ass-fuck the dude who made nicotine Maybe I should buy some Hundreds, wear some fuckin\' skinny jeans And follow in your footsteps like a motherfuckin\' millipede Centipede, make songs about Gucci and cigaweed Jerk with my friends like it\'s some motherfuckin\' little league No I ain\'t no fucking hipster, mister No I\'m not no fucking Kid Cudi, all my fucking fans love me Collaboration hits for fans screaming fuck buddies, yo, yo  I\'m drivin\' in a stolen truck, and I\'m probably fuckin\' drunk Wasted as fuck, can\'t walk it out, DJ Unk My nose is filled with coke and my license is revoked (Shut the fuck up!) Who the fuck told me not to spoke? Fuck everybody here, everybody vanish, I\'ll manage Hop off my dick and make a fucking sandwitch Everybody listening can suck my dick in Spanish Fuck you, faggot (Fuckin\' Bastard)  Yeah, um, as you can probably tell from listening to this record I was, I was probably angry, probably on my period But um, I didn’t mean to offend anyone, alright, I\'m lying, OF'

# %%
sia = SentimentIntensityAnalyzer()

# %%
dicts = []    

for song in corpus:
    scores = sia.polarity_scores(song)
    scores['lyrics'] = song
    dicts.append(scores)

df = pd.DataFrame(dicts)
df.head()
# Out:
#    compound                                             lyrics    neg    neu  \
# 0   -0.9991  This is what the devil plays before he goes to...  0.230  0.643
# 1   -0.9984  I'd tell him to eat a dick quicker than Mexica...  0.232  0.675
# 2   -0.9527  Hello, the Hype is so Mellow Bitch I'm dope an...  0.158  0.718
# 3   -0.9970  Got all the black bitches mad cause my main bi...  0.196  0.696
# 4   -0.9948  If this was a game I already know that I would...  0.207  0.658
#
#      pos
# 0  0.127
# 1  0.093
# 2  0.124
# 3  0.108
# 4  0.136

# %%
df['album'] = major_releases_df['album'].values
df['year'] = major_releases_df['year'].values
df.head()
# Out:
#    compound                                             lyrics    neg    neu  \
# 0   -0.9991  This is what the devil plays before he goes to...  0.230  0.643
# 1   -0.9984  I'd tell him to eat a dick quicker than Mexica...  0.232  0.675
# 2   -0.9527  Hello, the Hype is so Mellow Bitch I'm dope an...  0.158  0.718
# 3   -0.9970  Got all the black bitches mad cause my main bi...  0.196  0.696
# 4   -0.9948  If this was a game I already know that I would...  0.207  0.658
#
#      pos    album  year
# 0  0.127  Bastard  2009
# 1  0.093  Bastard  2009
# 2  0.124  Bastard  2009
# 3  0.108  Bastard  2009
# 4  0.136  Bastard  2009

# %%
df.groupby('year').mean()[['pos', 'neg', 'compound']].plot(kind='barh')

# %%
df.to_csv('tyler_sentiment.csv')

# %%
sentiment = pd.read_csv('tyler_sentiment.csv')

# %%
sentiment.drop('Unnamed: 0',axis=1,inplace=True)

# %%
grouped_by_album=pd.DataFrame(sentiment.groupby('album').mean()[['pos', 'neg', 'compound']])

# %%
grouped_by_album.index
# Out:
# Index(['Bastard', 'Cherry Bomb', 'Flower Boy', 'Goblin', 'IGOR', 'Wolf'], dtype='object', name='album')

# %%
grouped_by_album
# Out:
#                   pos       neg  compound
# album
# Bastard      0.102267  0.193533 -0.849980
# Cherry Bomb  0.116533  0.145933 -0.438253
# Flower Boy   0.102923  0.096538 -0.047846
# Goblin       0.091765  0.208176 -0.840494
# IGOR         0.142250  0.102083  0.030125
# Wolf         0.107111  0.182500 -0.448872

# %%
grouped_by_album=grouped_by_album.reindex(['Bastard','Goblin','Wolf','Cherry Bomb','Flower Boy','IGOR'])

# %%
grouped_by_album.plot(figsize=(12,7),kind='bar',color=['pink','red','orange'])
plt.tick_params(labelsize=15)
plt.legend(loc='lower right', fontsize=15)
plt.xticks(rotation=20)
plt.xlabel('Albums',size=20)
plt.ylabel('Scores',size=20)
plt.title('Tyler the Creator Albums\nBy Their Sentiment Score',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Tyler the Creator Albums\nBy Their Sentiment Score')

# %%
plt.title('Album: Bastard')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[0].plot(#figsize=(3,3),
    kind='barh',color=['black','whitesmoke','red'])

# %%
plt.title('Album: Goblin')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[1].plot(#figsize=(3,3),
    kind='barh',color=['whitesmoke','cornsilk','mediumaquamarine'])

# %%
plt.title('Album: Wolf')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[2].plot(#figsize=(3,3),
    kind='barh',color=['brown','olive','paleturquoise'])

# %%
plt.title('Album: Cherry Bomb')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[3].plot(#figsize=(3,3),
    kind='barh',color=['lightseagreen','pink','red'])

# %%
plt.title('Album: Flower Boy')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[4].plot(#figsize=(3,3),
    kind='barh',color=['orange','red','khaki'])

# %%
plt.title('Album: IGOR')
plt.ylabel('Category of\nSentiment',rotation=0)
plt.xlabel('Scores')
plt.axvline(0,color='k')
grouped_by_album.iloc[5].plot(#figsize=(3,3),
    kind='barh',color=['black','pink','grey'])
