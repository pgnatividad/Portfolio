# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup

# %%
url = "https://www.azlyrics.com/t/tylerthecreator.html"
res = requests.get(url)

# %%
res.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n<meta name="description" content="Tyler, The Creator lyrics - 122 song lyrics sorted by album, including &quot;EARFQUAKE&quot;, &quot;See You Again&quot;, &quot;RUNNING OUT OF TIME&quot;."> \r\n<meta name="keywords" content="Tyler, The Creator, Tyler, The Creator lyrics, discography, albums, songs">\r\n<meta name="robots" content="noarchive">\r\n<title>Tyler, The Creator Lyrics</title>\r\n\r\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">\r\n<link rel="stylesheet" href="//www.azlyrics.com/bsaz.css">\r\n\r\n<!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n<!--[if lt IE 9]>\r
# ...

# %%
soup = BeautifulSoup(res.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content='Tyler, The Creator lyrics - 122 song lyrics sorted by album, including "EARFQUAKE", "See You Again", "RUNNING OUT OF TIME".' name="description"/>
# <meta content="Tyler, The Creator, Tyler, The Creator lyrics, discography, albums, songs" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <title>Tyler, The Creator Lyrics</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="//www.azlyrics.com/bsaz.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# ...

# %%
soup.find('div',{'class':'album'})
# Out:
# <div class="album" id="16428">album: <b>"Bastard"</b> (2009)</div>

# %%
empty_list = []
for song_in_album in soup.find_all('div',{'class':'album'}):
    
    print (song_in_album)
# Out:
# <div class="album" id="16428">album: <b>"Bastard"</b> (2009)</div>
# <div class="album" id="16429">album: <b>"Goblin"</b> (2011)</div>
# <div class="album" id="24014">album: <b>"Wolf"</b> (2013)</div>
# <div class="album" id="37780">album: <b>"Cherry Bomb"</b> (2015)</div>
# <div class="album" id="48991">album: <b>"Flower Boy"</b> (2017)</div>
# <div class="album" id="63262">EP: <b>"Music Inspired By Illumination &amp; Dr. Seuss' The Grinch"</b> (2018)</div>
# <div class="album" id="68839">album: <b>"IGOR"</b> (2019)</div>
# <div class="album">other songs:</div>

# %%
soup.find('div',{'id':'listAlbum'})
# Out:
# <div id="listAlbum">
# <div class="album" id="16428">album: <b>"Bastard"</b> (2009)</div>
# <a href="../lyrics/tylerthecreator/bastard.html" target="_blank">Bastard</a><br/>
# <a href="../lyrics/tylerthecreator/seven.html" target="_blank">Seven</a><br/>
# <a href="../lyrics/tylerthecreator/oddtoddlers.html" target="_blank">Odd Toddlers</a><br/>
# <a href="../lyrics/tylerthecreator/french.html" target="_blank">French!</a><br/>
# <a href="../lyrics/tylerthecreator/blow.html" target="_blank">Blow</a><br/>
# <a href="../lyrics/tylerthecreator/pigsfly.html" target="_blank">Pigs Fly</a><br/>
# <a href="../lyrics/tylerthecreator/parade.html" target="_blank">Parade</a><br/>
# <a href="../lyrics/tylerthecreator/slowitdown.html" target="_blank">Slow It Down</a><br/>
# <a href="../lyrics/tylerthecreator/assmilk.html" target="_blank">AssMilk</a><br/>
# <a href="../lyrics/tylerthecreator/vcrwheels.html" target="_blank">VCR / Wheels</a><br/>
# ...

# %%
albums_and_songs = soup.find('div',{'id':'listAlbum'})

# %%
for album in albums_and_songs.find_all('div'):
    print(album.find('a'))
    print('next album')
# Out:
# None
# next album
# None
# next album
# None
# next album
# None
# next album
# None
# next album
# None
# next album
# None
# next album
# None
# next album
